# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshi0100/ML-Intern/blob/master/bitcoin_dataset(expanded_graph).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)

# %%
import pandas
import matplotlib.pyplot as plt
import numpy as np
df=pandas.read_csv('/content/drive/My Drive/dataset/bitcoin.csv')

# %%
df['Gross profit or loss']=df['Open']-df['Close']
df

# %%
df['Date'].replace('',np.nan,inplace=True)
df.dropna(subset=['Date'],inplace=True)
df.count()

# %%
a_values=np.array(df['Date'])
b_values=np.array(df['Gross profit or loss'])
plt.plot(a_values,b_values,'bo-',markersize=4)
plt.xlabel("Date")
plt.ylabel("Gross profit or loss")
plt.xticks(rotation=45)
plt.rcParams['figure.figsize']=(22,15)
plt.show()
