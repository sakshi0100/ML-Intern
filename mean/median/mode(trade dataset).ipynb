# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshi0100/ML-Intern/blob/master/mean/median/mode(trade%20dataset).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=False)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas
df=pandas.read_csv('/content/drive/My Drive/dataset/data.csv')
df.head()
# Out:
#         Date  Symbol  ...  Total Traded Quantity   Turnover (in Lakhs)
# 0  13-Apr-20      LT  ...                9462929              80158.97
# 1  09-Apr-20      LT  ...                6410629              52338.49
# 2  08-Apr-20      LT  ...                6151093              50037.53
# 3  07-Apr-20      LT  ...                5769216              46404.57
# 4  03-Apr-20      LT  ...                4268501              33009.75
#
# [5 rows x 10 columns]

# %%
df[' Mean']=df.iloc[:,4:8].mean(axis=1)
df[' Median']=df.iloc[:,4:8].median(axis=1)
df[' Mode']=df.iloc[:,lambda df: [3]].mode(axis=1)
df
# Out:
#          Date  Symbol  Series  ...       Mean    Median     Mode
# 0   13-Apr-20      LT      EQ  ...   852.5500   864.925   812.80
# 1   09-Apr-20      LT      EQ  ...   814.1375   808.900   834.35
# 2   08-Apr-20      LT      EQ  ...   811.2000   807.550   804.00
# 3   07-Apr-20      LT      EQ  ...   801.9625   801.925   805.00
# 4   03-Apr-20      LT      EQ  ...   777.8875   778.825   791.10
# 5   01-Apr-20      LT      EQ  ...   782.2125   774.950   806.85
# 6   31-Mar-20      LT      EQ  ...   808.2000   809.300   820.00
# 7   30-Mar-20      LT      EQ  ...   800.9125   798.825   801.00
# 8   27-Mar-20      LT      EQ  ...   845.0125   839.025   867.90
# 9   26-Mar-20      LT      EQ  ...   819.1875   840.150   787.75
# 10  25-Mar-20      LT      EQ  ...   742.6875   767.375   697.20
# 11  24-Mar-20      LT      EQ  ...   711.4125   708.950   755.00
# 12  23-Mar-20      LT      EQ  ...   740.2500   722.525   809.00
# ...

# %%
df.to_excel('modified.xlsx')
